# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from quantificationlib.baselines.cc import CC, PCC
from quantificationlib.baselines.ac import AC, PAC
from quantificationlib.multiclass.df import HDy
from quantificationlib.multiclass.em import EM

import matplotlib.pyplot as plt

import sys, os
sys.path.append(os.path.abspath(".."))

from src.legacy_cbms26.bags import generate_bags

from aeon.classification.deep_learning import FCNClassifier, LITETimeClassifier
# Out:
# 2026-02-05 15:16:09.004998: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = np.load("./data/processed/mitdb_preprocessed.npz")

X_train = data["X_train"]
X_test = data["X_test"]
y_train = data["y_train"]
y_test = data["y_test"]
rec_train = data["rec_train"]
rec_test = data["rec_test"]

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
print("Train positives:", np.sum(y_train==1))
print("Test positives:", np.sum(y_test==1))
# Out:
# Train shape: (77518, 360)
# Test shape: (35129, 360)
# Train positives: 46054
# Test positives: 28998

# %%
bags_X_test_100, bags_prev_test_100 = generate_bags(
    X_test, y_test,
    bag_size=100,
    n_bags=2000,
    random_state=42
)

bags_X_test_200, bags_prev_test_200 = generate_bags(
    X_test, y_test,
    bag_size=200,
    n_bags=2000,
    random_state=42
)

bags_X_test_500, bags_prev_test_500 = generate_bags(
    X_test, y_test,
    bag_size=500,
    n_bags=2000,
    random_state=42
)
# Out:
# [INFO] Positive samples: 28998, Negative samples: 6131.
# [INFO] Positive samples: 28998, Negative samples: 6131.
# [INFO] Positive samples: 28998, Negative samples: 6131.

# %%
results = {
    'bag_id': [],
    'bag_size': [],
    'method': [],
    'classifier': [],
    'mae': [],
    'pred_pos': [],
    'true_pos': [],
}

# %% [markdown]
# ## CC LITETime Predictions

# %%
estimator = LITETimeClassifier(random_state=42, save_best_model=True)
# estimator.fit(X_train, y_train)

cc = CC(estimator_test=estimator)
cc.fit(X_train, y_train)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770142888.291497 1433421 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9809 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2026-02-03 15:21:30.712792: I external/local_xla/xla/service/service.cc:163] XLA service 0x788eec007b90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-02-03 15:21:30.712805: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2026-02-03 15:21:30.759779: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-03 15:21:31.037298: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# ...

# %%
for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_100, bags_prev_test_100)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = cc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(100)
    results['method'].append('CC')
    results['classifier'].append('LITETime')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_200, bags_prev_test_200)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = cc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(200)
    results['method'].append('CC')
    results['classifier'].append('LITETime')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_500, bags_prev_test_500)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = cc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(500)
    results['method'].append('CC')
    results['classifier'].append('LITETime')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 4s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x788c10a82ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
results_df = pd.read_csv('../results/baselines_full_lite.csv', index_col=None)
results_df = results_df.drop(columns=['Unnamed: 0'], axis=1)

results_df.to_csv('./baselines_full_lite.csv', index=False)

# %%
results_df = pd.DataFrame(results)
results_df.to_csv('../results/baselines_full_lite.csv')

# %%
results_df.query('method == "CC" and bag_size == 200').mae.mean(), results_df.query('method == "CC" and bag_size == 200').mae.std()
# Out:
# (np.float64(0.12065), np.float64(0.07361054697706455))

# %% [markdown]
# ## CC Random Forest Predictions

# %%
estimator = RandomForestClassifier(n_estimators=150, random_state=42)

cc = CC(estimator_test=estimator)
cc.fit(X_train, y_train)
# Out:
# CC(estimator_test=RandomForestClassifier(n_estimators=150, random_state=42))

# %%
for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_100, bags_prev_test_100)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = cc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(100)
    results['method'].append('CC')
    results['classifier'].append('RF')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_200, bags_prev_test_200)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = cc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(200)
    results['method'].append('CC')
    results['classifier'].append('RF')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_500, bags_prev_test_500)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = cc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(500)
    results['method'].append('CC')
    results['classifier'].append('RF')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

# %%
results_df = pd.DataFrame(results)
results_df.to_csv('../results/baselines_full.csv', index=False)

# %%
results_df.query('method == "CC" and bag_size == 500').mae.mean(), results_df.query('method == "CC" and bag_size == 500').mae.std()
# Out:
# (np.float64(0.085195), np.float64(0.054394387115536444))

# %% [markdown]
# ## PCC SVM Predictions

# %%
estimator = SVC(kernel="rbf", probability=True)
pcc = PCC(estimator_test=estimator)
pcc.fit(X_train, y_train)
# Out:
# PCC(estimator_test=SVC(probability=True))

# %%
for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_100, bags_prev_test_100)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = pcc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(100)
    results['method'].append('PCC')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_200, bags_prev_test_200)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = pcc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(200)
    results['method'].append('PCC')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_500, bags_prev_test_500)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = pcc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(500)
    results['method'].append('PCC')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

# %%
results_df = pd.DataFrame(results)
results_df.to_csv('../results/baselines_full.csv', index=False)

# %%
results_df.query('method == "PCC" and bag_size == 500').mae.mean(), results_df.query('method == "PCC" and bag_size == 500').mae.std()
# Out:
# (np.float64(0.0917983386446137), np.float64(0.05533521001542947))

# %% [markdown]
# ## ACC SVM Predictions

# %%
estimator = SVC(kernel="rbf", probability=True)
acc = AC(estimator_train=estimator, estimator_test=estimator)
acc.fit(X_train, y_train)
# Out:
# AC(estimator_test=SVC(probability=True), estimator_train=SVC(probability=True))

# %%
for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_100, bags_prev_test_100)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = acc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(100)
    results['method'].append('ACC')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_200, bags_prev_test_200)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = acc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(200)
    results['method'].append('ACC')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_500, bags_prev_test_500)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = acc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(500)
    results['method'].append('ACC')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

# %%
results_df = pd.DataFrame(results)
results_df.to_csv('../results/baselines_full.csv', index=False)

# %%
results_df.query('method == "ACC" and bag_size == 100').mae.mean(), results_df.query('method == "ACC" and bag_size == 100').mae.std()
# Out:
# (np.float64(0.07399713286034569), np.float64(0.05051459678176381))

# %% [markdown]
# ## PACC SVM Predictions

# %%
estimator = SVC(kernel="rbf", probability=True)
pacc = PAC(estimator_train=estimator, estimator_test=estimator)

pacc.fit(X_train, y_train)
# Out:
# PAC(estimator_test=SVC(probability=True), estimator_train=SVC(probability=True))

# %%
for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_100, bags_prev_test_100)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = pacc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(100)
    results['method'].append('PACC')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_200, bags_prev_test_200)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = pacc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(200)
    results['method'].append('PACC')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_500, bags_prev_test_500)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = pacc.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(500)
    results['method'].append('PACC')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

# %%
results_df = pd.DataFrame(results)
results_df.to_csv('../results/baselines.csv')

# %%
results_df.query('method == "PACC" and bag_size == 500').mae.mean(), results_df.query('method == "PACC" and bag_size == 500').mae.std()
# Out:
# (np.float64(0.08267521675038454), np.float64(0.04991264569598562))

# %% [markdown]
# ## HDy LR Predictions

# %%
estimator = LogisticRegression(max_iter=500)
hdy = HDy(estimator_train=estimator, estimator_test=estimator)
hdy.fit(X_train, y_train)
# Out:
# HDy(estimator_test=LogisticRegression(max_iter=500),
#     estimator_train=LogisticRegression(max_iter=500))

# %%
for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_100, bags_prev_test_100)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = hdy.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(100)
    results['method'].append('HDy')
    results['classifier'].append('LR')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_200, bags_prev_test_200)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = hdy.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(200)
    results['method'].append('HDy')
    results['classifier'].append('LR')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_500, bags_prev_test_500)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = hdy.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(500)
    results['method'].append('HDy')
    results['classifier'].append('LR')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

# %%
results_df = pd.DataFrame(results)
results_df.to_csv('../results/baselines.csv')

# %%
results_df.query('method == "HDy" and bag_size == 100').mae.mean(), results_df.query('method == "HDy" and bag_size == 100').mae.std()
# Out:
# (np.float64(0.11191567948384959), np.float64(0.08328660090976307))

# %% [markdown]
# ## EMQ SVM Predictions

# %%
estimator = SVC(kernel="rbf", probability=True)
em = EM(estimator_train=estimator, estimator_test=estimator)
em.fit(X_train, y_train)

# %%
for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_100, bags_prev_test_100)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = em.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(100)
    results['method'].append('EMQ')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_200, bags_prev_test_200)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = em.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(200)
    results['method'].append('EMQ')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

for idx, (Xb, prev_true) in enumerate(zip(bags_X_test_500, bags_prev_test_500)):
    Xb_f = Xb.reshape(len(Xb), -1)
    prev_pred = em.predict(Xb_f)

    results['bag_id'].append(idx)
    results['bag_size'].append(500)
    results['method'].append('EMQ')
    results['classifier'].append('SVM')
    results['mae'].append(abs(prev_pred[1] - prev_true))
    results['pred_pos'].append(prev_pred[1])
    results['true_pos'].append(prev_true)

# %%
results_df = pd.DataFrame(results)
results_df.to_csv('../results/baselines.csv')

# %%
results_df.query('method == "EMQ" and bag_size == 500').mae.mean(), results_df.query('method == "EMQ" and bag_size == 500').mae.std()
# Out:
# (np.float64(0.0629023544059563), np.float64(0.04111141420499999))
